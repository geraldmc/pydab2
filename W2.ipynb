# %%
# Advanced Python - Functions (12.13.2024)

# %% [markdown]
# ## **Contents**
# 1. [Python Scoping - Part I](#id1)
# 2. [Python Scoping - Part II](#id2)
# 3. [3](#id3)
# 4. [4](#id4)
# 5. [5](#id5)
# 6. [6](#id6)
# 7. [7](#id7)
# 8. [8](#id8)
# 9. [9](#id9)
# 10. [10](#id10)

# %% [markdown]
# <a name="id1"></a>

# %%
# 1 Scope in Python - Order of search:

# L - Local
# E - Enclosing function
# G - Global
# B - Built-in

# If inside a function body, start searching from here:
# L - Local
# E - Enclosing function
# If outside a function, start searching from here:
# G - Global
# B - Built-in

x = 100 # The variable "x" is not in a function, search starts in Globals.
print(f"x = {x}")
print(f"Is x in globals? {'x' in globals()}.\n")

for i in range(10):
  y = i * 2 # The variables "x" and "y" are not in a function, still global!

print(f"Is y in globals? {'y' in globals()}.")
print(f"Is i in globals? {'i' in globals()}.\n")

# IF NOT IN A FUNCTION BODY, ALL IS GLOBAL (or built-in)!

def hello_from_another_function():
  print(f"Hello from inside another function!")

def local_func(): # Inside a function body, BUT x is still a global value.
  print(f"Inside local_func the value of x is {x}.")
  hello_from_another_function() #

local_func() # the 'other' function is in the global namespace.
# Out:
# x = 100
# Is x in globals? True.
#
# Is y in globals? True.
# Is i in globals? True.
#
# Inside local_func the value of x is 100.
# Hello from inside another function!

# %% [markdown]
# <a name="id2"></a>

# %%
# 2 Scope in Python - UnboundLocalError
import dis

def foo():
  print(f"The value of x: {x}")
  x = x + 1. # exception is expected since we haven't assigned a value to x.

try:
  foo()
except UnboundLocalError:
  print("Var 'x' has not been assigned. ")

def foo():
  x = x + 1 # exception is *unexpected*, we've already assigned a value.
  print(f"The value of x: {x}")

try:
  foo()
except UnboundLocalError:
  print("Var 'x' has not been assigned. ")
# Out:
# Var 'x' has not been assigned.
# Var 'x' has not been assigned.

# %% [markdown]
# <a name="id3"></a>

# %%
# 3

# %% [markdown]
# <a name="id4"></a>

# %%
# 4

# %% [markdown]
# <a name="id5"></a>

# %%
# 5

# %% [markdown]
# <a name="id6"></a>

# %%
# 6

# %% [markdown]
# <a name="id7"></a>

# %%
# 7

# %% [markdown]
# <a name="id8"></a>

# %%
# 8

# %% [markdown]
# <a name="id9"></a>

# %%
# 9

# %% [markdown]
# <a name="id10"></a>

# %%
# 10
